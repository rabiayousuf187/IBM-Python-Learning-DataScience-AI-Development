# %% [markdown]
# ## Cheat Sheet: Lists and Tuples

# %% [markdown]
# #Use this cheat sheet for various packages/methods, their descriptions, and examples.

# %% [markdown]
# ## 1. List Content

# %% [markdown]
# ### Key Point:
# An ordered, mutable collection enclosed in square brackets `[]` that stores multiple comma-separated items.

# %% [markdown]
# ### Creating a List

# %% [markdown]
# A list is a built-in data type that represents an ordered and mutable collection of elements. Lists are enclosed in square brackets [] and elements are separated by commas.

# %%
fruits = [] 
fruits
#OR
fruits = ["apple", "banana", "orange", "mango"]
fruits
# Out:
# ['apple', 'banana', 'orange', 'mango']

# %% [markdown]
# ### append()

# %% [markdown]
# Adds a single element directly to the end of the list, modifying it in place.

# %%
fruits = ["apple", "banana", "orange"] 
fruits.append("mango") 
print(fruits)
# Out:
# ['apple', 'banana', 'orange', 'mango']

# %% [markdown]
# ### copy() and clone (Sciling Shorthanded)[:] Difference

# %%
#Returns a shallow duplicate copy of the list so modifications do not alter the original list.
## If concern index is not List then changein Duplicate did not chnage the orginial List
initial_list = [1, 2, 3, 4, 5] 
# Both create an independent top-level list
updated_list = initial_list.copy() 
print('initial List = ', my_list) 
print('updated List = ', updated_list)
# Out:
# initial List =  [1, 2, 3, 4, 5]
# updated List =  [1, 2, 3, 4, 5]

# %%
#Shared Weakness: Nested DataBecause both are shallow copies, 
#if the list contains another mutable container (like a nested list), 
#changes to that nested container will leak through and affect the original in both approaches.

initial_list = [[1, 2], 3]

copy_slicing = initial_list[:]
copy_method = initial_list.copy()

# Changing a nested element impacts everything
copy_slicing[0].append(99) 

print('initial_list == ', initial_list)    # Output: [[1, 2, 99], 3] (Leaked!)
print('copy_slicing == ', copy_slicing)
print('copy_method == ', copy_method) # Output: [[1, 2, 99], 3] (Leaked!)
# Out:
# initial_list ==  [[1, 2, 99], 3]
# copy_slicing ==  [[1, 2, 99], 3]
# copy_method ==  [[1, 2, 99], 3]

# %%
### count()

# %% [markdown]
# The count() method is used to count the number of occurrences of a specific element in a list in Python.

# %%
my_list = [1, 'a', 'a', 4, 2, 5, 2, 'a'] 
count = my_list.count('a') 
print(count) 
# Output: 4
# Out:
# 3

# %%
### del

# %% [markdown]
# The del statement is used to remove an element from list. It removes the element at the specified index.

# %%
my_list = [10, 20, 30, 40, 50] 
del my_list[2]
my_list
# Out:
# [10, 20, 40, 50]

# %%
### extend()

# %% [markdown]
# The extend() method is used to add multiple elements to a list. It takes an iterable (such as another list, tuple, or string) and appends each element of the iterable to the original list.

# %%
#list_name.extend(iterable) 
fruits = ["apple", "banana", "orange"] 
more_fruits = ["mango", "grape"] 
fruits.extend(more_fruits) 
print(fruits)
# Out:
# ['apple', 'banana', 'orange', 'mango', 'grape']

# %%
### Indexing

# %% [markdown]
# Indexing in a list allows you to access individual elements by their position. In Python, indexing starts from 0 for the first element and goes up to 'length_of_list - 1'

# %%
my_list = [10, 20, 30, 40, 50] 
print(my_list[0]) 
# Output: 10 (accessing the first element) 
print(my_list[-1]) 
# Output: 50 (accessing the last element using negative indexing)
# Out:
# 10
# 50

# %%
### insert()

# %% [markdown]
# The insert() method is used to insert an element.

# %%
#list_name.insert(index, element) 
my_list = [1, 2, 3, 4, 5] 
my_list.insert(2, 6) 
print(my_list)
# Out:
# [1, 2, 6, 3, 4, 5]

# %% [markdown]
# ### Modifying a List

# %% [markdown]
# You can use indexing to modify or assign new values to specific elements in the list.

# %%
my_list = [10, 20, 30, 40, 50] 
my_list[1] = 25 # Modifying the second element 
print(my_list) 
# Output: [10, 25, 30, 40, 50]|
# Out:
# [10, 25, 30, 40, 50]

# %%
### pop()

# %% [markdown]
# The pop() method is another way to remove an element from a list in Python. It removes and returns the element at the specified index. If you don't provide an index to the pop() method, it will remove and return the last element of the list by default

# %%
## Example 1:

my_list = [10, 20, 30, 40, 50] 
removed_element = my_list.pop(2) # Removes and returns the element at index 2 
print(removed_element) 
# Output: 30 

print(my_list) 
# Output: [10, 20, 40, 50]
# Out:
# 30
# [10, 20, 40, 50]

# %%
### Example 2:
my_list = [10, 20, 30, 40, 50] 
removed_element = my_list.pop() # Removes and returns the last element 
print(removed_element) 
# Output: 50 

print(my_list) 
# Output: [10, 20, 30, 40]
# Out:
# 50
# [10, 20, 30, 40]

# %%
### remove()

# %% [markdown]
# To remove an element from a list. The remove() method removes the first occurrence of the specified value.

# %%
my_list = [10, 20, 30, 40, 50] 
my_list.remove(30) # Removes the element 30 
print(my_list) 
# Output: [10, 20, 40, 50]
# Out:
# [10, 20, 40, 50]

# %%
### reverse()

# %% [markdown]
# The reverse() method is used to reverse the order of elements in a list

# %%
my_list = [1, 2, 3, 4, 5] 
my_list.reverse() 
print(my_list) 
# Output: [5, 4, 3, 2, 1]
# Out:
# [5, 4, 3, 2, 1]

# %%
### Slicing()

# %% [markdown]
# You can use slicing to access a range of elements from a list.

# %%
# list_name[start:end:step] 
my_list = [1, 2, 3, 4, 5] 
print(my_list[1:4]) 
# Output: [2, 3, 4] (elements from index 1 to 3)

print(my_list[:3]) 
# Output: [1, 2, 3] (elements from the beginning up to index 2) 

print(my_list[2:]) 
# Output: [3, 4, 5] (elements from index 2 to the end) 

print(my_list[::2]) 
# Output: [1, 3, 5] (every second element)
# Out:
# [2, 3, 4]
# [1, 2, 3]
# [3, 4, 5]
# [1, 3, 5]

# %%
### sort()

# %% [markdown]
# The sort() method is used to sort the elements of a list in ascending order. If you want to sort the list in descending order, you can pass the 'reverse=True' argument to the sort() method.

# %%
#Example 1:
my_list = [5, 2, 8, 1, 9] 
my_list.sort() 
print(my_list) 
# Output: [1, 2, 5, 8, 9]
# Out:
# [1, 2, 5, 8, 9]

# %%
#Example 2:
my_list = [5, 2, 8, 1, 9] 
my_list.sort(reverse=True) 
print(my_list) 
# Output: [9, 8, 5, 2, 1]
# Out:
# [9, 8, 5, 2, 1]

# %% [markdown]
# ## 2. Tuples

# %%
### count()

# %% [markdown]
# The count() method for a tuple is used to count how many times a specified element appears in the tuple.

# %%
#tuple.count(value)
fruits = ("apple", "banana", "apple","apple", "orange")
print(fruits.count("apple")) #Counts the number of times apple is found in tuple.
#Output: 2
# Out:
# 3

# %%
### index()

# %% [markdown]
# The index() method in a tuple is used to find the first occurrence of a specified value and returns its position (index). If the value is not found, it raises a ValueError.

# %%
#tuple.index(value) 
fruits = ("apple", "banana", "orange","apple")
print(fruits.index("apple")) #Returns the index value at which apple is present.
#Output: 0
# Out:
# 0

# %%
### sum()

# %% [markdown]
# The sum() function in Python can be used to calculate the sum of all elements in a tuple, provided that the elements are numeric (integers or floats).

# %%
#sum(tuple) 

numbers = (10, 20, 5, 30)
print(sum(numbers))
#Output: 65
# Out:
# 65

# %%
### min() and max()

# %% [markdown]
# Find the smallest (min()) or largest (max()) element in a tuple.

# %%
numbers = (10, 20, 5, 30)
print(min(numbers))  
#Output: 5
print(max(numbers))
#Output: 30
# Out:
# 5
# 30

# %%
### len()

# %% [markdown]
# Get the number of elements in the tuple using len().

# %%
#len(tuple)
fruits = ("apple", "banana", "orange")
print(len(fruits)) #Returns length of the tuple.
#Output: 3
# Out:
# 3
